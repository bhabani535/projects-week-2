# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('aggregate_covid_country.csv',parse_dates=['Date'])
df
# Out:
#             Date             Country  Confirmed  Recovered  Deaths
# 0     2020-01-22         Afghanistan          0          0       0
# 1     2020-01-22             Albania          0          0       0
# 2     2020-01-22             Algeria          0          0       0
# 3     2020-01-22             Andorra          0          0       0
# 4     2020-01-22              Angola          0          0       0
# ...          ...                 ...        ...        ...     ...
# 23683 2020-05-26  West Bank and Gaza        429        365       3
# 23684 2020-05-26      Western Sahara          9          6       1
# 23685 2020-05-26               Yemen        249         10      49
# 23686 2020-05-26              Zambia        920        336       7
# 23687 2020-05-26            Zimbabwe         56         25       4
#
# [23688 rows x 5 columns]

# %%
df['Date'].value_counts()
# Out:
# 2020-04-09    188
# 2020-05-03    188
# 2020-02-08    188
# 2020-05-19    188
# 2020-01-26    188
#              ...
# 2020-03-26    188
# 2020-03-13    188
# 2020-02-29    188
# 2020-02-16    188
# 2020-03-27    188
# Name: Date, Length: 126, dtype: int64

# %%
df.head(60)
# Out:
#          Date                   Country  Confirmed  Recovered  Deaths
# 0  2020-01-22               Afghanistan          0          0       0
# 1  2020-01-22                   Albania          0          0       0
# 2  2020-01-22                   Algeria          0          0       0
# 3  2020-01-22                   Andorra          0          0       0
# 4  2020-01-22                    Angola          0          0       0
# 5  2020-01-22       Antigua and Barbuda          0          0       0
# 6  2020-01-22                 Argentina          0          0       0
# 7  2020-01-22                   Armenia          0          0       0
# 8  2020-01-22                 Australia          0          0       0
# 9  2020-01-22                   Austria          0          0       0
# 10 2020-01-22                Azerbaijan          0          0       0
# 11 2020-01-22                   Bahamas          0          0       0
# ...

# %%
df.tail(60)
# Out:
#             Date                           Country  Confirmed  Recovered  \
# 23628 2020-05-26                            Norway       8383       7727
# 23629 2020-05-26                              Oman       8118       2067
# 23630 2020-05-26                          Pakistan      57705      18314
# 23631 2020-05-26                            Panama      11447       6379
# 23632 2020-05-26                  Papua New Guinea          8          8
# 23633 2020-05-26                          Paraguay        877        382
# 23634 2020-05-26                              Peru     129751      52906
# 23635 2020-05-26                       Philippines      14669       3412
# 23636 2020-05-26                            Poland      22074      10020
# 23637 2020-05-26                          Portugal      31007      18096
# 23638 2020-05-26                             Qatar      47207      11844
# 23639 2020-05-26                           Romania      18429      11874
# ...

# %%
df.corr()
# Out:
#            Confirmed  Recovered    Deaths
# Confirmed   1.000000   0.810991  0.929718
# Recovered   0.810991   1.000000  0.778094
# Deaths      0.929718   0.778094  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23688 non-null  datetime64[ns]
#  1   Country    23688 non-null  object
#  2   Confirmed  23688 non-null  int64
#  3   Recovered  23688 non-null  int64
#  4   Deaths     23688 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 925.4+ KB

# %%
df.describe(include='all')
# Out:
#                        Date     Country     Confirmed      Recovered  \
# count                 23688       23688  2.368800e+04   23688.000000
# unique                  126         188           NaN            NaN
# top     2020-04-09 00:00:00  Mozambique           NaN            NaN
# freq                    188         126           NaN            NaN
# first   2020-01-22 00:00:00         NaN           NaN            NaN
# last    2020-05-26 00:00:00         NaN           NaN            NaN
# mean                    NaN         NaN  7.969368e+03    2581.801714
# std                     NaN         NaN  5.842109e+04   15143.101257
# min                     NaN         NaN  0.000000e+00       0.000000
# 25%                     NaN         NaN  0.000000e+00       0.000000
# 50%                     NaN         NaN  1.800000e+01       1.000000
# 75%                     NaN         NaN  7.300000e+02     123.000000
# max                     NaN         NaN  1.680913e+06  384902.000000
#
# ...

# %%
df.describe()
# Out:
#           Confirmed      Recovered        Deaths
# count  2.368800e+04   23688.000000  23688.000000
# mean   7.969368e+03    2581.801714    526.935030
# std    5.842109e+04   15143.101257   3992.815956
# min    0.000000e+00       0.000000      0.000000
# 25%    0.000000e+00       0.000000      0.000000
# 50%    1.800000e+01       1.000000      0.000000
# 75%    7.300000e+02     123.000000     13.000000
# max    1.680913e+06  384902.000000  98913.000000

# %%
df.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
Data_dates=pd.DataFrame()
Data_dates['Country']=df['Country']
Data_dates['Month']=df['Date'].dt.month_name()
Data_dates['Year']=df['Date'].dt.year
Data_dates['Day']=df['Date'].dt.day_name()
Data_dates['Day_n']=df['Date'].dt.day
Data_dates['Deaths']=df['Deaths']
Data_dates['Confirmed']=df['Confirmed']
Data_dates['Recovered']=df['Recovered']
Data_dates
# Out:
#                   Country    Month  Year        Day  Day_n  Deaths  Confirmed  \
# 0             Afghanistan  January  2020  Wednesday     22       0          0
# 1                 Albania  January  2020  Wednesday     22       0          0
# 2                 Algeria  January  2020  Wednesday     22       0          0
# 3                 Andorra  January  2020  Wednesday     22       0          0
# 4                  Angola  January  2020  Wednesday     22       0          0
# ...                   ...      ...   ...        ...    ...     ...        ...
# 23683  West Bank and Gaza      May  2020    Tuesday     26       3        429
# 23684      Western Sahara      May  2020    Tuesday     26       1          9
# 23685               Yemen      May  2020    Tuesday     26      49        249
# 23686              Zambia      May  2020    Tuesday     26       7        920
# 23687            Zimbabwe      May  2020    Tuesday     26       4         56
#
#        Recovered
# ...

# %%
sns.barplot(x='Country',y='Deaths',data=Data_dates)

# %%
sns.barplot(x='Month',y='Deaths',data=Data_dates)

# %%
sns.barplot(x='Confirmed',y='Deaths',data=df)

# %%
sns.barplot(x='Recovered',y='Deaths',data=df)

# %%
df.plot.scatter(x='Recovered',y='Deaths')

# %%
sns.lineplot(x='Date',y='Deaths',data=df)

# %%
sns.lineplot(x='Day',y='Deaths',data=Data_dates)

# %%
sns.lineplot(x='Day_n',y='Deaths',data=Data_dates)

# %%
sns.barplot?

# %%
df.skew()
# Out:
# Confirmed    18.674502
# Recovered    10.662286
# Deaths       14.218167
# dtype: float64

# %%
#Lets treat the skewness
import numpy as np
for index in df.skew().index:
    if df.skew().loc[index]>0.5:
        df[index]=np.cbrt(df[index])
    if df.skew().loc[index]<-0.5:
        df[index]=np.cbrt(df[index])

# %%
df.skew()
# Out:
# Confirmed    3.264431
# Recovered    3.363246
# Deaths       4.171327
# dtype: float64

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Country']= label_encoder.fit_transform(df['Country']) 
Data_dates['Month']= label_encoder.fit_transform(Data_dates['Month'])
Data_dates['Day']= label_encoder.fit_transform(Data_dates['Day'])

# %%
Data_dates
# Out:
#        Country  Month  Year  Day  Day_n  Deaths  Confirmed  Recovered
# 0            0      2  2020    6     22       0          0          0
# 1            1      2  2020    6     22       0          0          0
# 2            2      2  2020    6     22       0          0          0
# 3            3      2  2020    6     22       0          0          0
# 4            4      2  2020    6     22       0          0          0
# ...        ...    ...   ...  ...    ...     ...        ...        ...
# 23683      183      4  2020    5     26       3        429        365
# 23684      184      4  2020    5     26       1          9          6
# 23685      185      4  2020    5     26      49        249         10
# 23686      186      4  2020    5     26       7        920        336
# 23687      187      4  2020    5     26       4         56         25
#
# [23688 rows x 8 columns]

# %%
df.corr()
# Out:
#            Confirmed  Recovered    Deaths
# Confirmed   1.000000   0.926766  0.948520
# Recovered   0.926766   1.000000  0.874524
# Deaths      0.948520   0.874524  1.000000

# %%
# Out:
#   File "<ipython-input-56-f11cc33f9e2c>", line 1
#     for i in collist[]:
#                      ^
# SyntaxError: invalid syntax

# %%
df['Country']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 23683    183
# 23684    184
# 23685    185
# 23686    186
# 23687    187
# Name: Country, Length: 23688, dtype: int32

# %%
sns.boxplot(df['Country'])

# %%
sns.boxplot(df['Confirmed'])

# %%
sns.boxplot(df['Recovered'])

# %%
sns.boxplot(df['Deaths'])

# %% [markdown]
# outliers are present

# %% [raw]
# z score

# %%
# cant do it cause there will be irregularities in row

# %%
dfx=df.drop(['Date','Deaths'],axis=1)
dfx
# Out:
#        Country  Confirmed  Recovered
# 0            0   0.000000   0.000000
# 1            1   0.000000   0.000000
# 2            2   0.000000   0.000000
# 3            3   0.000000   0.000000
# 4            4   0.000000   0.000000
# ...        ...        ...        ...
# 23683      183   7.541987   7.146569
# 23684      184   2.080084   1.817121
# 23685      185   6.291195   2.154435
# 23686      186   9.725888   6.952053
# 23687      187   3.825862   2.924018
#
# [23688 rows x 3 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 23683    1.442250
# 23684    1.000000
# 23685    3.659306
# 23686    1.912931
# 23687    1.587401
# Name: Deaths, Length: 23688, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(dfx)
x
# Out:
# array([[-1.72286214, -0.61844615, -0.53372045],
#        [-1.70443581, -0.61844615, -0.53372045],
#        [-1.68600948, -0.61844615, -0.53372045],
#        ...,
#        [ 1.68600948, -0.06737439, -0.26311138],
#        [ 1.70443581,  0.23348465,  0.3394964 ],
#        [ 1.72286214, -0.28332303, -0.16644744]])

# %%
x=pd.DataFrame(x,columns=dfx.columns)
x
# Out:
#         Country  Confirmed  Recovered
# 0     -1.722862  -0.618446  -0.533720
# 1     -1.704436  -0.618446  -0.533720
# 2     -1.686009  -0.618446  -0.533720
# 3     -1.667583  -0.618446  -0.533720
# 4     -1.649157  -0.618446  -0.533720
# ...         ...        ...        ...
# 23683  1.649157   0.042188   0.363929
# 23684  1.667583  -0.436243  -0.305480
# 23685  1.686009  -0.067374  -0.263111
# 23686  1.704436   0.233485   0.339496
# 23687  1.722862  -0.283323  -0.166447
#
# [23688 rows x 3 columns]

# %% [markdown]
# Machine learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lnr=LinearRegression()
final_r_state=maxr2_score(lnr,x,y)
# Out:
# r2 score corresponding to  42  is  0.9044002604691779
# r2 score corresponding to  43  is  0.8966498345827734
# r2 score corresponding to  44  is  0.8958306145447841
# r2 score corresponding to  45  is  0.8964654196456936
# r2 score corresponding to  46  is  0.89021000437025
# r2 score corresponding to  47  is  0.8905000386294118
# r2 score corresponding to  48  is  0.8989054177064388
# r2 score corresponding to  49  is  0.8928227494419271
# r2 score corresponding to  50  is  0.9053672228439733
# r2 score corresponding to  51  is  0.9073397872273058
# r2 score corresponding to  52  is  0.8864922922914972
# r2 score corresponding to  53  is  0.8942644190786341
# r2 score corresponding to  54  is  0.9103743748351096
# r2 score corresponding to  55  is  0.9050132986470256
# r2 score corresponding to  56  is  0.899107094985684
# r2 score corresponding to  57  is  0.9065491887863463
# r2 score corresponding to  58  is  0.9023808341965113
# ...

# %%
a_score=cross_val_score(lnr,x,y,cv=10)
print(a_score)
print(a_score.mean())
print(np.std(a_score))
# Out:
# [-1.37653285  0.33508615  0.62874225  0.75971601  0.75789011  0.86434125
#   0.90098099  0.89252437  0.88052882  0.86298667]
# 0.5506263764963688
# 0.6631472909715337

# %%
#final Model

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y,random_state = 96,test_size=0.30)
lnr.fit(x_train,y_train)
lnrpred=lnr.predict(x_test)
print('Predicted Deaths: ',lnrpred)
print('Real Deaths: ',y_test)
# Out:
# Predicted Deaths:  [ 0.41703053 -0.44990399  3.12411622 ... -0.44557554 -0.52781603
#  -0.52673392]
# Real Deaths:  14828    1.259921
# 16582    0.000000
# 19221    2.466212
# 19131    0.000000
# 10413    1.000000
#            ...
# 22659    2.843867
# 5122     0.000000
# 8494     0.000000
# 4810     0.000000
# 11201    0.000000
# Name: Deaths, Length: 7107, dtype: float64

# %%
print('R2 score',r2_score(lnrpred,y_test))
print('Mean Absolute Error',mean_absolute_error(lnrpred,y_test))
print('Mean Squared Error',mean_squared_error(lnrpred,y_test))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(lnrpred,y_test)))
# Out:
# R2 score 0.898611125417595
# Mean Absolute Error 0.832654293593541
# Mean Squared Error 1.9184922903681116
# Root Mean Squared Error 1.385096491356509

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100,random_state=96)
rf.fit(x_train,y_train)
rfpred=rf.predict(x_test)
print('Predicted Deaths: ',rfpred)
print('Real Deaths: ',y_test)
# Out:
# Predicted Deaths:  [1.17573447 0.         2.46621207 ... 0.         0.         0.        ]
# Real Deaths:  14828    1.259921
# 16582    0.000000
# 19221    2.466212
# 19131    0.000000
# 10413    1.000000
#            ...
# 22659    2.843867
# 5122     0.000000
# 8494     0.000000
# 4810     0.000000
# 11201    0.000000
# Name: Deaths, Length: 7107, dtype: float64

# %%
print('R2 score',r2_score(rfpred,y_test))
print('Mean Absolute Error',mean_absolute_error(rfpred,y_test))
print('Mean Squared Error',mean_squared_error(rfpred,y_test))
print('Root Mean Squared Error',np.sqrt(mean_squared_error(rfpred,y_test)))
# Out:
# R2 score 0.9913155475395145
# Mean Absolute Error 0.15361417094042956
# Mean Squared Error 0.1781579224038896
# Root Mean Squared Error 0.4220875766993025

# %%
from sklearn.externals import joblib
joblib.dump(rf,'coviddeathrf.obj')
# Out:
# ['coviddeathrf.obj']
